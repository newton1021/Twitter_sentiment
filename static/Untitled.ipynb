# %%
from database import DataBase as DB
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
db = DB()

# %%
(pset, pwords, nset, nwords) = db.getWordList()

# %%
wc = WordCloud(width = 800, height = 800, margin = 0).generate(" ".join(pwords))

# %%
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %%
wc2 =  WordCloud(width = 800, height = 800, margin = 0).generate(" ".join(nwords))

# %%
plt.imshow(wc2, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %%
df = db.getCurrentData()
dfp = df[df.est_positivity == 1]
dfn = df[df.est_positivity == -1]
presults = dfp.groupby("search_key").count()
nresults = dfn.groupby("search_key").count()

# %%
presults
# Out:
#             id  name  date  retweet_count  tweet_text  tweet_cleaned  \
# search_key
# ABBA        18    18    18             18          18             18
# puppy       14    14    14             14          14             14
# texas        5     5     5              5           5              5
# war         12    12    12             12          12             12
#
#             est_positivity
# search_key
# ABBA                    18
# puppy                   14
# texas                    5
# war                     12

# %%
nresults
# Out:
#             id  name  date  retweet_count  tweet_text  tweet_cleaned  \
# search_key
# ABBA         5     5     5              5           5              5
# puppy        9     9     9              9           9              9
# texas        3     3     3              3           3              3
# war          5     5     5              5           5              5
#
#             est_positivity
# search_key
# ABBA                     5
# puppy                    9
# texas                    3
# war                      5

# %%
pwords
# Out:
# ['happy',
#  '🥰',
#  'prayer',
#  'father',
#  'see',
#  'great',
#  'eternal',
#  'purpose',
#  'let',
#  'look',
#  'beyond',
#  'common',
#  'events',
#  'day',
#  'make',
#  'big',
#  'time',
#  'posted',
#  'poll',
#  'definitively',
#  'proved',
#  'good',
#  'return',
#  'top',
#  'years',
#  'new',
#  'song',
#  'glad',
#  'lay',
#  'love',
#  '’',
#  'amazing',
#  'wait',
#  '’',
#  'new',
#  'song',
#  'indictment',
#  '5',
#  'others',
#  'confirms',
#  'fears',
#  'many',
#  'venality',
#  'premier',
#  'feel',
#  'like',
#  'would',
#  'huge',
#  '’',
#  'actual',
#  'dancing',
#  'queen',
#  '“',
#  'hung',
#  '”',
#  'definitely',
#  '’',
#  'best',
#  'song',
#  'happy',
#  'music',
#  'god',
#  'tier',
#  'spot',
#  'person',
#  'good',
#  'taste',
#  'culture',
#  'bought',
#  'first',
#  'volume',
#  'cover',
#  'two',
#  'one',
#  'every',
#  'song',
#  'makes',
#  'want',
#  'cry',
#  '’',
#  'good',
#  'fine',
#  'level',
#  'must',
#  'listen',
#  '’',
#  '‘',
#  'generation',
#  '’',
#  'album',
#  'like',
#  'absolute',
#  'mom',
#  'receiving',
#  'information',
#  'new',
#  'music',
#  'years',
#  'spirit',
#  'received',
#  'make',
#  'slaves',
#  'live',
#  'fear',
#  'rather',
#  'spirit',
#  'received',
#  'way',
#  'ignored',
#  'right',
#  'seems',
#  'people',
#  'voted',
#  'many',
#  'fascists',
#  'going',
#  'take',
#  'lot',
#  'effort',
#  'rid',
#  'people',
#  'deadline',
#  '’',
#  'also',
#  'going',
#  'need',
#  'huge',
#  'water',
#  'desalinization',
#  'plants',
#  'along',
#  'pacific',
#  'coast',
#  'southern',
#  'thought',
#  'gun',
#  'owners',
#  'responsible',
#  'weapons',
#  'problem',
#  'enjoy',
#  'weekly',
#  'tests',
#  'unemployment',
#  'line',
#  'choose',
#  'line',
#  'stay',
#  'apart',
#  'think',
#  'mean',
#  'delicious',
#  'puppy',
#  '’',
#  'fun',
#  'puppy',
#  'expands',
#  'size',
#  'earth',
#  'takes',
#  '😰',
#  'preemie',
#  'really',
#  'pretty',
#  'puppy',
#  'please',
#  'give',
#  'puppy',
#  'full',
#  'time',
#  'art',
#  'new',
#  'release',
#  'please',
#  'share',
#  'like',
#  'puppy',
#  'trip',
#  'hot',
#  'freaks',
#  'puppy',
#  'princess',
#  '“',
#  'even',
#  'though',
#  'fire',
#  'hot',
#  'kid',
#  'jumped',
#  'save',
#  'puppy',
#  '”',
#  'checkmate',
#  'atheists',
#  'bright',
#  'side',
#  'getting',
#  'new',
#  'puppy',
#  'cane',
#  'mastiff',
#  'born',
#  'today',
#  'would',
#  'cage',
#  'nice',
#  'absolutely',
#  '’',
#  'even',
#  'offering',
#  'puppy',
#  'puppy',
#  'truly',
#  'unique',
#  'rare',
#  'via',
#  'submitted',
#  'august',
#  'interaction',
#  'love',
#  'giving',
#  'puppy',
#  'eyes',
#  'saying',
#  'mom',
#  'please',
#  'punish',
#  'perks',
#  'love',
#  'much',
#  'loves',
#  'hes',
#  'toxic',
#  'love',
#  'love',
#  'wish',
#  'people',
#  'real',
#  'loads',
#  'gunshots',
#  'area',
#  'sounds',
#  'like',
#  'war',
#  'zone',
#  'super',
#  'unusual',
#  'literally',
#  'sounds',
#  'like',
#  'someone',
#  'wrote',
#  'weeks',
#  'cover',
#  'modern',
#  'war',
#  'film',
#  'needs',
#  'get',
#  'creative',
#  'less',
#  'fun',
#  'fact',
#  'trade',
#  'deficit',
#  'china',
#  'reached',
#  '’',
#  'fighting',
#  'war',
#  'tight',
#  'winning',
#  'photos',
#  'started',
#  'infantry',
#  'regiment',
#  'followed',
#  'mix',
#  'sadness',
#  'lives',
#  'innocent',
#  'father',
#  'saw',
#  'great',
#  'depression',
#  'dust',
#  'bowl',
#  'war',
#  'polio',
#  'pandemic',
#  'war',
#  '’',
#  'fantastic',
#  'honestly',
#  'god',
#  'war',
#  'fairly',
#  'faithful',
#  'depictions',
#  'gods',
#  'great',
#  'sure',
#  '’',
#  'twice',
#  'long',
#  'mini',
#  'games',
#  'sound',
#  'conservative',
#  'barbaric',
#  'treatment',
#  'needs',
#  'another',
#  'revolution',
#  'maniac',
#  'kind',
#  'one',
#  'true',
#  'suppose',
#  'result',
#  'invading',
#  'divide']

# %%
import enchant
d = enchant.Dict("en_US")

# %%
for word in pwords:
    if d.check(word):
        print(word)
    else:
        print(f'----{word}')
        continue
# Out:
# love
# ----abba
# wish
# ----swedish
# people
# real
# ----berserkanna
# happy
# ----saturday
# ----abba
# 🥰
# prayer
# ----abba
# father
# see
# great
# eternal
# purpose
# let
# look
# beyond
# common
# events
# day
# make
# ----me…
# big
# time
# ----inmspain
# posted
# poll
# definitively
# proved
# good
# ----abba
# ----can…
# ----abba
# return
# ----uk
# top
# ----10
# ----40
# years
# new
# song
# ----bontenjiku
# ----aahh
# ----im
# glad
# lay
# love
# ----abba
# ’
# amazing
# ----lt3
# ----amandahewittt
# wait
# ’
# new
# ----abba
# song
# indictment
# ----abba
# ----kyrai
# 5
# others
# confirms
# fears
# many
# venality
# ----nigerias
# premier
# ----law…
# feel
# like
# ----historia
# would
# huge
# ----abba
# ----stan
# ’
# actual
# dancing
# queen
# ----popbanghugh
# “
# hung
# ”
# definitely
# ----abba
# ’
# best
# ----madonna
# song
# ----powerfmuganda
# ----profetug
# ----256karungi
# ----ijm
# ----capmauganda
# ----blackabba
# ----haircentralug
# ----piatokampala
# happy
# ----23rd
# ----birthday…
# ----parralex0889
# ----abba
# music
# god
# tier
# spot
# person
# good
# taste
# culture
# bought
# first
# volume
# ----jojos
# ----bc
# cover
# two
# ----fugos
# one
# ----abba
# every
# ----abba
# song
# makes
# want
# cry
# ----bc
# ’
# good
# ----brickchainey
# ----jakebrodes
# ----ethnicohioan
# fine
# level
# ----stache
# ----leggsgreggs
# must
# listen
# ----ateens
# ’
# ‘
# ----abba
# generation
# ’
# album
# like
# absolute
# ----bangers
# mom
# receiving
# information
# new
# ----abba
# music
# ----40
# years
# spirit
# received
# make
# slaves
# live
# fear
# rather
# spirit
# received
# ----b…
# ----tedcruz
# ----breitbartnews
# way
# ignored
# ----texas
# ----cancun
# right
# seems
# people
# ----texas
# voted
# many
# fascists
# going
# take
# lot
# effort
# rid
# people
# deadline
# ’
# also
# going
# need
# huge
# water
# desalinization
# plants
# along
# pacific
# coast
# southern
# ----central…
# ----austinpolice
# thought
# ----texas
# gun
# owners
# ----100
# responsible
# weapons
# ----times…
# problem
# enjoy
# weekly
# tests
# unemployment
# line
# choose
# line
# stay
# ----6ft
# apart
# ----kee…
# ----trv216
# ----jayneco04310055
# think
# mean
# delicious
# puppy
# ----hehehehe
# ----freyaamari
# ’
# fun
# puppy
# expands
# size
# earth
# takes
# 😰
# ----mandylicious
# ----alexandraknew
# ----nettiebergin
# ----nurseasaurusrex
# preemie
# ----clothesdiapers
# really
# ----availa…
# ----anarchonudity
# pretty
# puppy
# ----chongster62
# please
# give
# ----louise
# puppy
# full
# time
# ----♥️♥️
# ----nft
# art
# new
# release
# please
# share
# like
# puppy
# trip
# ----nft
# ----nftart
# ----nftcollector…
# ----siolasart
# hot
# freaks
# puppy
# princess
# ----chizuruuwu
# ----nessasea
# ----hulkgamerxx
# “
# even
# though
# fire
# hot
# kid
# jumped
# save
# puppy
# ”
# checkmate
# atheists
# bright
# side
# ----im
# getting
# new
# puppy
# cane
# ----corso
# ----italian
# mastiff
# born
# today
# ----❤️
# ----n…
# ----dirtibong
# ----lucipuppy
# would
# cage
# nice
# ----kristodynamics
# ----eeberquist
# ----eatinginmycar
# absolutely
# ’
# even
# offering
# puppy
# ----doglover
# puppy
# truly
# unique
# rare
# ----pupper
# via
# submitted
# august
# ----03
# ----2021
# ----0516pm
# ----essaycapital
# ----poop4u…
# ----lrt
# ----omg
# ----norton
# ----michiko
# interaction
# love
# ----😭😭❤️❤️
# ----nort
# giving
# ----michi
# puppy
# eyes
# saying
# ----ahah
# mom
# please
# ----dont
# punish
# ----ruuvi6
# ----edward
# perks
# love
# much
# loves
# ----bella
# ----buuuuuut
# hes
# ----lowkey
# toxic
# ----asf
# love
# ----wholesome…
# ----omg
# loads
# gunshots
# area
# sounds
# like
# war
# zone
# super
# unusual
# literally
# sounds
# like
# someone
# ----i…
# war
# ’
# fantastic
# wrote
# weeks
# ----mintlounge
# cover
# modern
# ----hindi
# war
# film
# needs
# get
# creative
# less
# ----worshi…
# ----th1nkaboutit1
# ----suidaila
# ----botofrus1
# ----benwilkinson
# ----aviationintel
# fun
# fact
# trade
# deficit
# china
# reached
# ----new…
# ’
# fighting
# war
# tight
# ----hammies…
# winning
# ----36
# photos
# ----gbnews
# started
# infantry
# regiment
# followed
# mix
# sadness
# lives
# innocent
# ----pe…
# ----ansgartodinson
# honestly
# god
# war
# fairly
# faithful
# depictions
# ----norse
# gods
# great
# ----cassidenaep
# father
# ----93
# saw
# great
# depression
# dust
# bowl
# ----wwii
# ----korean
# war
# polio
# pandemic
# ----civ…
# ----herrera4324
# ----xthundercheese
# ----angelushector
# ----ign
# sure
# ’
# twice
# long
# mini
# games
# ----completion…
# ----mjgranger1
# ----laralogan
# ----omg
# sound
# ----navie
# conservative
# barbaric
# treatment
# ----prisones
# ----surren…
# ----vasiliarkhipov1
# ----repkatieporter
# ----america
# needs
# another
# revolution
# maniac
# ----maga
# kind
# one
# ----establish…
# ----heccinv
# ----davastarragain
# ----thats
# true
# suppose
# ----thats
# ----100
# result
# ----911
# invading
# ----iraq
# divide
# ----the…

# %%
filtered_words = []
for word in pwords:
    if d.check(word):
        filtered_words.append(word)
    else:
        continue

# %%
filtered_words
# Out:
# ['love',
#  'wish',
#  'people',
#  'real',
#  'happy',
#  '🥰',
#  'prayer',
#  'father',
#  'see',
#  'great',
#  'eternal',
#  'purpose',
#  'let',
#  'look',
#  'beyond',
#  'common',
#  'events',
#  'day',
#  'make',
#  'big',
#  'time',
#  'posted',
#  'poll',
#  'definitively',
#  'proved',
#  'good',
#  'return',
#  'top',
#  'years',
#  'new',
#  'song',
#  'glad',
#  'lay',
#  'love',
#  '’',
#  'amazing',
#  'wait',
#  '’',
#  'new',
#  'song',
#  'indictment',
#  '5',
#  'others',
#  'confirms',
#  'fears',
#  'many',
#  'venality',
#  'premier',
#  'feel',
#  'like',
#  'would',
#  'huge',
#  '’',
#  'actual',
#  'dancing',
#  'queen',
#  '“',
#  'hung',
#  '”',
#  'definitely',
#  '’',
#  'best',
#  'song',
#  'happy',
#  'music',
#  'god',
#  'tier',
#  'spot',
#  'person',
#  'good',
#  'taste',
#  'culture',
#  'bought',
#  'first',
#  'volume',
#  'cover',
#  'two',
#  'one',
#  'every',
#  'song',
#  'makes',
#  'want',
#  'cry',
#  '’',
#  'good',
#  'fine',
#  'level',
#  'must',
#  'listen',
#  '’',
#  '‘',
#  'generation',
#  '’',
#  'album',
#  'like',
#  'absolute',
#  'mom',
#  'receiving',
#  'information',
#  'new',
#  'music',
#  'years',
#  'spirit',
#  'received',
#  'make',
#  'slaves',
#  'live',
#  'fear',
#  'rather',
#  'spirit',
#  'received',
#  'way',
#  'ignored',
#  'right',
#  'seems',
#  'people',
#  'voted',
#  'many',
#  'fascists',
#  'going',
#  'take',
#  'lot',
#  'effort',
#  'rid',
#  'people',
#  'deadline',
#  '’',
#  'also',
#  'going',
#  'need',
#  'huge',
#  'water',
#  'desalinization',
#  'plants',
#  'along',
#  'pacific',
#  'coast',
#  'southern',
#  'thought',
#  'gun',
#  'owners',
#  'responsible',
#  'weapons',
#  'problem',
#  'enjoy',
#  'weekly',
#  'tests',
#  'unemployment',
#  'line',
#  'choose',
#  'line',
#  'stay',
#  'apart',
#  'think',
#  'mean',
#  'delicious',
#  'puppy',
#  '’',
#  'fun',
#  'puppy',
#  'expands',
#  'size',
#  'earth',
#  'takes',
#  '😰',
#  'preemie',
#  'really',
#  'pretty',
#  'puppy',
#  'please',
#  'give',
#  'puppy',
#  'full',
#  'time',
#  'art',
#  'new',
#  'release',
#  'please',
#  'share',
#  'like',
#  'puppy',
#  'trip',
#  'hot',
#  'freaks',
#  'puppy',
#  'princess',
#  '“',
#  'even',
#  'though',
#  'fire',
#  'hot',
#  'kid',
#  'jumped',
#  'save',
#  'puppy',
#  '”',
#  'checkmate',
#  'atheists',
#  'bright',
#  'side',
#  'getting',
#  'new',
#  'puppy',
#  'cane',
#  'mastiff',
#  'born',
#  'today',
#  'would',
#  'cage',
#  'nice',
#  'absolutely',
#  '’',
#  'even',
#  'offering',
#  'puppy',
#  'puppy',
#  'truly',
#  'unique',
#  'rare',
#  'via',
#  'submitted',
#  'august',
#  'interaction',
#  'love',
#  'giving',
#  'puppy',
#  'eyes',
#  'saying',
#  'mom',
#  'please',
#  'punish',
#  'perks',
#  'love',
#  'much',
#  'loves',
#  'hes',
#  'toxic',
#  'love',
#  'loads',
#  'gunshots',
#  'area',
#  'sounds',
#  'like',
#  'war',
#  'zone',
#  'super',
#  'unusual',
#  'literally',
#  'sounds',
#  'like',
#  'someone',
#  'war',
#  '’',
#  'fantastic',
#  'wrote',
#  'weeks',
#  'cover',
#  'modern',
#  'war',
#  'film',
#  'needs',
#  'get',
#  'creative',
#  'less',
#  'fun',
#  'fact',
#  'trade',
#  'deficit',
#  'china',
#  'reached',
#  '’',
#  'fighting',
#  'war',
#  'tight',
#  'winning',
#  'photos',
#  'started',
#  'infantry',
#  'regiment',
#  'followed',
#  'mix',
#  'sadness',
#  'lives',
#  'innocent',
#  'honestly',
#  'god',
#  'war',
#  'fairly',
#  'faithful',
#  'depictions',
#  'gods',
#  'great',
#  'father',
#  'saw',
#  'great',
#  'depression',
#  'dust',
#  'bowl',
#  'war',
#  'polio',
#  'pandemic',
#  'sure',
#  '’',
#  'twice',
#  'long',
#  'mini',
#  'games',
#  'sound',
#  'conservative',
#  'barbaric',
#  'treatment',
#  'needs',
#  'another',
#  'revolution',
#  'maniac',
#  'kind',
#  'one',
#  'true',
#  'suppose',
#  'result',
#  'invading',
#  'divide']

# %%
# Out:
# ()
